# %% [markdown]
# # Runing Transboard

# %%
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_640x640_coco17_tpu-8"

# %%
# !tensorboard --logdir=training/TF2/training/{PATH_TO_MODEL}/

# %%
tensorboard dev upload --logdir \
    'training/TF2/training/faster_rcnn_resnet101_v1_640x640_coco17_tpu-8/'

# %% [markdown]
# ### DetectionBoxes_Precision graph images
# ![](DetectionBoxes_Precision.png)![DetectionBoxes_Precision.png](attachment:DetectionBoxes_Precision.png)

# %% [markdown]
# ### DetectionBoxes recall
# ![](DetectionBoxes_recall.png)![DetectionBoxes_recall.png](attachment:DetectionBoxes_recall.png)

# %% [markdown]
# ### Loss
# ![](loss.png)![loss.png](attachment:loss.png)![loss2.png](attachment:loss2.png)![learning_rate.png](attachment:learning_rate.png)

# %% [markdown]
# ## learning rate per secound
# ![](learning_rate.png)![learning_rate.png](attachment:learning_rate.png)

# %% [markdown]
# ## Projector
# ![](Projector.png)![Projector.png](attachment:Projector.png)
